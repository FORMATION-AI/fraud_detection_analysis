# %%
# %%writefile .gitignore
# # Python cache files
# __pycache__/
# *.pyc
#
# # Virtual environment
# .venv/
#
# images/
#
# # Artifacts and model files
# artifacts/
#
# # Optional system files
# .DS_Store
# Out:
# Overwriting .gitignore
